# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import fitz

# %%
doc = fitz.open('Page 3 Figma.pdf')
page = doc.load_page(0)
text = page.get_text()
pdf_text = ''.join(text)
pdf_text_list = text.split('\n')
pdf_final_list = [l.replace('\n','').strip() for l in pdf_text_list if l.replace('\n','').strip()]
pdf_final_list
# Out:
# ['One of the world’s',
#  'most-trusted',
#  'browsers',
#  'An award-winning',
#  'antivirus',
#  'Safe connection to',
#  'any Wi-Fi',
#  'Avoid infected',
#  'websites & emails',
#  'After your download is finished, the installation file will install:',
#  '1) Avast Free Antivirus',
#  '2) Google Chrome Browser',
#  'Free download',
#  'Get Google Chrome browser plus our award-winning antivirus',
#  'protection, together in one free download. Browse with even more',
#  'privacy and stay protected against viruses and other malware —',
#  'supported by two trusted and fully compatible tools.',
#  'Get Google Chrome +',
#  'Avast Free Antivirus in one',
#  'free download',
#  'Stronger together',
#  'A single download gets you Google Chrome, one of the world’s most trusted and safe browsers — plus Avast Free Antivirus to add even more',
#  'online privacy and to keep you secure against viruses and other malware.',
#  'Use a browser you can',
#  'trust',
#  'Google Chrome is a trusted name amongst browsers. With easy-to-use',
#  'privacy controls — which you can use alongside Avast’s protection —',
#  'it’s simple to keep your sensitive data safe and browse with true',
#  'confidence.',
#  'Find out more',
#  'Enjoy an award-winning,',
#  'powerful, free antivirus',
#  'Get our light, powerful free antivirus protection. Block viruses,',
#  'malware, and other online threats, scan your Wi-Fi network for',
#  'weaknesses, and strengthen your online privacy. Trusted by 435 million',
#  'users worldwide.',
#  'After your download is finished, click on the downloaded file and follow the installation instructions. Installations will run in the following order:',
#  '1) Avast Free Antivirus',
#  '2) Google Chrome Browser',
#  'Free download',
#  'Get Google Chrome with the powerful protection of',
#  'Avast Free Antivirus',
#  '© 2024 Gen Digital Inc. All rights reserved.',
#  '•',
#  'Privacy policy',
#  '•',
#  'Products policy',
#  '•',
#  'License agreements',
#  '•',
#  'Cookie preferences',
#  'About Avast',
#  '•',
#  'Go to homepage']

# %%
pdf_text_final = ' '.join(pdf_final_list)
pdf_text_final
# Out:
# 'One of the world’s most-trusted browsers An award-winning antivirus Safe connection to any Wi-Fi Avoid infected websites & emails After your download is finished, the installation file will install: 1) Avast Free Antivirus 2) Google Chrome Browser Free download Get Google Chrome browser plus our award-winning antivirus protection, together in one free download. Browse with even more privacy and stay protected against viruses and other malware — supported by two trusted and fully compatible tools. Get Google Chrome + Avast Free Antivirus in one free download Stronger together A single download gets you Google Chrome, one of the world’s most trusted and safe browsers — plus Avast Free Antivirus to add even more online privacy and to keep you secure against viruses and other malware. Use a browser you can trust Google Chrome is a trusted name amongst browsers. With easy-to-use privacy controls — which you can use alongside Avast’s protection — it’s simple to keep your sensitive data safe and browse with true confidence. Find out more Enjoy an award-winning, powerful, free antivirus Get our light, powerful free antivirus protection. Block viruses, malware, and other online threats, scan your Wi-Fi network for weaknesses, and strengthen your online privacy. Trusted by 435 million users worldwide. After your download is finished, click on the downloaded file and follow the installation instructions. Installations will run in the following order: 1) Avast Free Antivirus 2) Google Chrome Browser Free download Get Google Chrome with the powerful protection of Avast Free Antivirus © 2024 Gen Digital Inc. All rights reserved. • Privacy policy • Products policy • License agreements • Cookie preferences About Avast • Go to homepage'

# %%
url = "file:///C:/Users/Kunal.Keni/Desktop/assignment/assignment%205/Page%203%20HTML.html"
html = urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')


text_content = soup.get_text(separator="\n")

# Split text into lines
lines = text_content.splitlines()

# Remove empty lines and strip whitespace
html_lines = [line.strip() for line in lines if line.strip()]

# %%
html_para = ' '.join(html_lines)
html_para = html_para.replace(' ,',',')
html_para = html_para.replace('\xa0',' ')

# %%
missing_in_html = []
for element_of_pdf in pdf_final_list:
    if element_of_pdf.lower() not in html_para.lower():
        missing_in_html.append(element_of_pdf)

# %%
for element in missing_in_html:
    text_instances = page.search_for(element)
    for inst in text_instances:
        highlight = page.add_highlight_annot(inst)
        highlight.update()



doc.save("output3.pdf", garbage=4, deflate=True, clean=True)

# %%
# Out:
#   Cell In[9], line 1
#     jupyter nbconvert test_html.ipynb --to python
#             ^
# SyntaxError: invalid syntax
