# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import fitz

# %%
doc = fitz.open('Page 3 Figma.pdf')
page = doc.load_page(0)
text = page.get_text()
pdf_text = ''.join(text)
pdf_text_list = text.split('\n')
pdf_final_list = [l.replace('\n','').strip() for l in pdf_text_list if l.replace('\n','').strip()]
pdf_final_list
# Out:
# ['One of the world’s',
#  'most-trusted',
#  'browsers',
#  'An award-winning',
#  'antivirus',
#  'Safe connection to',
#  'any Wi-Fi',
#  'Avoid infected',
#  'websites & emails',
#  'After your download is finished, the installation file will install:',
#  '1) Avast Free Antivirus',
#  '2) Google Chrome Browser',
#  'Free download',
#  'Get Google Chrome browser plus our award-winning antivirus',
#  'protection, together in one free download. Browse with even more',
#  'privacy and stay protected against viruses and other malware —',
#  'supported by two trusted and fully compatible tools.',
#  'Get Google Chrome +',
#  'Avast Free Antivirus in one',
#  'free download',
#  'Stronger together',
#  'A single download gets you Google Chrome, one of the world’s most trusted and safe browsers — plus Avast Free Antivirus to add even more',
#  'online privacy and to keep you secure against viruses and other malware.',
#  'Use a browser you can',
#  'trust',
#  'Google Chrome is a trusted name amongst browsers. With easy-to-use',
#  'privacy controls — which you can use alongside Avast’s protection —',
#  'it’s simple to keep your sensitive data safe and browse with true',
#  'confidence.',
#  'Find out more',
#  'Enjoy an award-winning,',
#  'powerful, free antivirus',
#  'Get our light, powerful free antivirus protection. Block viruses,',
#  'malware, and other online threats, scan your Wi-Fi network for',
#  'weaknesses, and strengthen your online privacy. Trusted by 435 million',
#  'users worldwide.',
#  'After your download is finished, click on the downloaded file and follow the installation instructions. Installations will run in the following order:',
#  '1) Avast Free Antivirus',
#  '2) Google Chrome Browser',
#  'Free download',
#  'Get Google Chrome with the powerful protection of',
#  'Avast Free Antivirus',
#  '© 2024 Gen Digital Inc. All rights reserved.',
#  '•',
#  'Privacy policy',
#  '•',
#  'Products policy',
#  '•',
#  'License agreements',
#  '•',
#  'Cookie preferences',
#  'About Avast',
#  '•',
#  'Go to homepage']

# %%
pdf_text_final = ' '.join(pdf_final_list)
pdf_text_final
# Out:
# 'One of the world’s most-trusted browsers An award-winning antivirus Safe connection to any Wi-Fi Avoid infected websites & emails After your download is finished, the installation file will install: 1) Avast Free Antivirus 2) Google Chrome Browser Free download Get Google Chrome browser plus our award-winning antivirus protection, together in one free download. Browse with even more privacy and stay protected against viruses and other malware — supported by two trusted and fully compatible tools. Get Google Chrome + Avast Free Antivirus in one free download Stronger together A single download gets you Google Chrome, one of the world’s most trusted and safe browsers — plus Avast Free Antivirus to add even more online privacy and to keep you secure against viruses and other malware. Use a browser you can trust Google Chrome is a trusted name amongst browsers. With easy-to-use privacy controls — which you can use alongside Avast’s protection — it’s simple to keep your sensitive data safe and browse with true confidence. Find out more Enjoy an award-winning, powerful, free antivirus Get our light, powerful free antivirus protection. Block viruses, malware, and other online threats, scan your Wi-Fi network for weaknesses, and strengthen your online privacy. Trusted by 435 million users worldwide. After your download is finished, click on the downloaded file and follow the installation instructions. Installations will run in the following order: 1) Avast Free Antivirus 2) Google Chrome Browser Free download Get Google Chrome with the powerful protection of Avast Free Antivirus © 2024 Gen Digital Inc. All rights reserved. • Privacy policy • Products policy • License agreements • Cookie preferences About Avast • Go to homepage'

# %%
url = "file:///C:/Users/Kunal.Keni/Desktop/assignment/assignment%205/Page%203%20HTML.html"
html = urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')


text_content = soup.get_text(separator="\n")

# Split text into lines
lines = text_content.splitlines()

# Remove empty lines and strip whitespace
html_lines = [line.strip() for line in lines if line.strip()]

# %%
html_lines
# Out:
# ['Get  Google Chrome + Avast Free Antivirus in one free download',
#  'Privacy preference center',
#  'By clicking "Accept all" you allow cookies that improve your experience on our site, help us analyze site performance and usage, and enable us to show relevant marketing content. You can manage cookie settings below. By clicking “Confirm selection” you agree with the current settings. See',
#  'Cookies policy',
#  'Accept all',
#  'Manage consent settings',
#  'Necessary cookies',
#  'Always Active',
#  'Necessary cookies help make a website usable by enabling basic functions like page navigation and access to secure areas of the website. The website cannot function properly without these cookies.',
#  'Preference cookies',
#  'Preference cookies',
#  'Preference cookies enable a website to remember information that changes the way the website behaves or looks, such as your preferred language or the region that you are in. De-selecting these cookies may result in improper functionality and setting of the website.',
#  'Performance cookies',
#  'Performance cookies',
#  'Performance cookies help us improve our website by analyzing how visitors use it and interact with it. De-selecting these cookies may result in poorly-designed content and slow site performance.',
#  'Marketing cookies',
#  'Marketing cookies',
#  'Marketing cookies are used to track visitors across websites. The intention is to display ads that are relevant and engaging for the individual user and thereby more valuable for publishers and third party advertisers. De-selecting these cookies may result in seeing advertising that is not as relevant to you.',
#  'Targeting cookies',
#  'Switch Label',
#  'label',
#  'These cookies may be set through our site by our advertising partners. They may be used by those companies to build a profile of your interests and show you relevant adverts on other sites. They do not store directly personal information, but are based on uniquely identifying your browser and internet device. If you do not allow these cookies, you will experience less targeted advertising.',
#  'Social media cookies',
#  'Switch Label',
#  'label',
#  'These cookies are set by a range of social media services that we have added to the site to enable you to share our content with your friends and networks. They are capable of tracking your browser across other sites and building up a profile of your interests. This may impact the content and messages you see on other websites you visit. If you do not allow these cookies you may not be able to use or see these sharing tools.',
#  'Back Button',
#  'Back',
#  'Search Icon',
#  'Filter Icon',
#  'Clear',
#  'checkbox label',
#  'label',
#  'Apply',
#  'Cancel',
#  'Consent',
#  'Leg.Interest',
#  'checkbox label',
#  'label',
#  'checkbox label',
#  'label',
#  'checkbox label',
#  'label',
#  'Confirm selection',
#  'In order to view this page correctly, you must have a JavaScript-enabled browser and have JavaScript turned on. We apologize for any inconvenience.',
#  'Learn how to enable it',
#  '.',
#  'We’re sorry, your browser appears to be outdated.',
#  'To see the content of this webpage correctly, please update to the latest version or install a new browser for free, such as',
#  'Avast Secure Browser',
#  'or',
#  'Google Chrome',
#  '.',
#  'After your download is finished, the installation file will install:',
#  '1) Avast free Antivirus',
#  '2) Google Chrome Browser',
#  'Free download',
#  'Free download',
#  'Get Google Chrome + Avast Free Antivirus in one free download',
#  'Get Google Chrome browser plus our award-winning antivirus protection, together in one free download. Browse with even more privacy and stay protected against viruses and other malware — supported by two trusted and fully compatible tools.',
#  'Free download',
#  'Free download',
#  'After your download is finished, the installation file will install:',
#  '1) Avast free Antivirus',
#  '2) Google Chrome Browser',
#  '+',
#  'Two powerful and fully compatible tools designed to keep you safe online — together.',
#  'One of the world’s most-trusted browsers',
#  'An award-winning antivirus',
#  'Safe connection to any Wi-Fi',
#  'Avoid infected websites & emails',
#  'Stronger together',
#  'A single download gets you',
#  'Google Chrome',
#  ', one of the world’s most trusted and safe browsers — plus',
#  'Avast Free Antivirus',
#  'to add even more online privacy and to keep you secure against viruses and other malware.',
#  'Use a browser you can trust',
#  'Google Chrome is a trusted name amongst browsers. With easy-to-use privacy controls — which you can use alongside Avast’s protection — it’s simple to keep your sensitive data safe and browse with true confidence.',
#  'Enjoy an award-winning, powerful, free antivirus',
#  'Get our light, powerful free antivirus protection. Block viruses, malware, and other online threats, scan your Wi-Fi network for weaknesses, and strengthen your online privacy. Trusted by 435 million users worldwide.',
#  'Protect your device with an award-winning antivirus',
#  'Our award-winning antivirus scans your device in real time, protecting you against viruses and other malware like ransomware and spyware.',
#  'Scan Wi-Fi networks for vulnerabilities',
#  'Automatically scan and connect safely to any Wi-Fi network, even unsecured public networks.',
#  'Avoid malicious websites and email attachments',
#  'Get alerts and block potentially malicious websites, files, and email attachments before you open them.',
#  'Work or play in peace — Do Not Disturb Mode',
#  'Block distracting popups and other interruptions when you’re gaming, watching movies, or presenting in fullscreen.',
#  'Hide info',
#  'Find out more',
#  'Get Google Chrome with the powerful protection of Avast Free Antivirus',
#  'Free download',
#  'Free download',
#  'After your download is finished, click on the downloaded file and follow the installation instructions. Installations will run in the following order:',
#  '1) Avast Free Antivirus',
#  '2) Google Chrome Browser',
#  'Close',
#  '+',
#  'Almost done!',
#  'Click the downloaded file to finish installing your free',
#  'Google Chrome + Avast Free Antivirus bundle.',
#  'Download',
#  'If your download did not start automatically, please',
#  'click here',
#  '.',
#  'Confirm installation',
#  'Click the downloaded file and follow the simple instructions.',
#  'Avast Free Antivirus will install first, then Google Chrome.',
#  'Enjoy both products',
#  'Now you can browse with even more security and confidence. Enjoy!',
#  'Click this file to start installing the bundle',
#  '© 2024 Gen Digital Inc.',
#  'All rights reserved.',
#  'Privacy policy',
#  'Products policy',
#  'License Agreements',
#  'Cookie Preferences',
#  'About Avast',
#  'Go to homepage',
#  'Close',
#  'Almost done!',
#  'Complete installation by clicking your downloaded file and following the instructions.',
#  'Initiating download...',
#  'Note:',
#  'If your download did not start automatically, please',
#  'click here',
#  '.',
#  'Need Help?',
#  'Please call',
#  '855-745-3255',
#  'Click this file to start installing Avast.']

# %%
html_para = ' '.join(html_lines)
html_para = html_para.replace(' ,',',')

# %%
missing_in_html = []
for element_of_pdf in pdf_final_list:
    if element_of_pdf.lower() not in html_para.lower():
        missing_in_html.append(element_of_pdf)

# %%
missing_in_html
# Out:
# ['•', '•', '•', '•', '•']

# %%
for element in missing_in_html:
    text_instances = page.search_for(element)
    for inst in text_instances:
        highlight = page.add_highlight_annot(inst)
        highlight.update()



doc.save("output3.pdf", garbage=4, deflate=True, clean=True)
