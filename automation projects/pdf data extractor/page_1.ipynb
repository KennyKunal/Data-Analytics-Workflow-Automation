# %%
from PyPDF2 import PdfReader
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup
import os
import google.generativeai as genai

# %% [markdown]
# # Reading pdf

# %% [markdown]
# ## PyPDF2

# %%
with open('Page 1 Figma.pdf', 'rb') as f:
    pdf_reader = PdfReader(f)

    num_pages = len(pdf_reader.pages)

    for page_number in range(num_pages):
        page = pdf_reader.pages[page_number]
        pdf_text = page.extract_text()

        # Remove non-alphanumeric characters and spaces
        # pdf_text = re.sub(r'[^a-zA-Z0-9]+', '', pdf_text)

# %%
pdf_text
# Out:
# 'A w a r d - w i n n i n g  \na n t i v i r u s  f o r  M a cD o e s n ’ t  s l o w  y o u r  \nd e v i c eH u n d r e d s  o f  \nm i l l i o n s  o f  u s e r s  \nw o r l d w i d e3 0 +  y e a r s  o f  \nc y b e r s e c u r i t y  \ne x p e r t i s eAppro v ed Mac \nSecurit y2022\nBes t macOS \nSecurit yJanuar y 2024\nGreat8,396 reviews on30- da y mone y -back guarant ee\nG e t  p r e m i u m\nF r e e  d o w n l o a dThink dif f erently ,  liv e saf elyF ree antivirus f or Macantivirus\nY our Mac is no t immune t o threats — \nbut our free Mac antivirus pro t ec ts y ou on 3 frontsMalw are isn ’ t the only threat t o y our Mac.  Malicious w ebsit es and vulnerable Wi-Fi ne tw ork s can also jeopardiz e y our saf e ty and priv ac y .  A v as t \nSecurity f or Mac pro vides more pro t ec tion agains t all 3 threats ,  and our premium v ersion also helps e xpose Wi-Fi intruders and helps s t op \nransom w are.\nA n t i - m a l w a r e  s e c u r i t yW e b  a n d  E m a i l  S h i e
# ...

# %% [markdown]
# ## correcting the pdf using gemini api

# %%
os.environ['GOOGLE_API_KEY'] = 'AIzaSyB2x8g0UgvK-T8ljHgBQgGGqpP1ljSreDc'
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content(f'{pdf_text} fix this text only there should be no space in words that make sense')

# %%
response.text.replace('\n',' ')
# Out:
# 'A ward-winning antivirus for MacDoesn’t slow your deviceHundreds of millions of users worldwide30+ years of cybersecurity expertiseApproved Mac Security2022Best macOS SecurityJanuary 2024Great8,396 reviews on30- day money-back guaranteeGet premiumFree downloadThink differently, live safelyFree antivirus for MacAntivirusYour Mac is not immune to threats — but our free Mac antivirus protects you on 3 frontsMalware isn’t the only threat to your Mac. Malicious websites and vulnerable Wi-Fi networks can also jeopardize your safety and privacy. Avast Security for Mac provides more protection against all 3 threats, and our premium version also helps expose Wi-Fi intruders and helps stop ransomware.Anti-malware securityWeb and Email ShieldsWi-Fi security scanWi-Fi intruder alerts (premium)Ransomware Shield (premium)See all anti-malware featuresAnti-malware protection for your MacYour macOS might stop some malware variants, but it can’t help you if you’re already infected. Avast’s free antiv
# ...

# %%
final_pdf_text = response.text.replace('\n',' ')

# %%
final_pdf_text
# Out:
# 'A ward-winning antivirus for MacDoesn’t slow your deviceHundreds of millions of users worldwide30+ years of cybersecurity expertiseApproved Mac Security2022Best macOS SecurityJanuary 2024Great8,396 reviews on30- day money-back guaranteeGet premiumFree downloadThink differently, live safelyFree antivirus for MacAntivirusYour Mac is not immune to threats — but our free Mac antivirus protects you on 3 frontsMalware isn’t the only threat to your Mac. Malicious websites and vulnerable Wi-Fi networks can also jeopardize your safety and privacy. Avast Security for Mac provides more protection against all 3 threats, and our premium version also helps expose Wi-Fi intruders and helps stop ransomware.Anti-malware securityWeb and Email ShieldsWi-Fi security scanWi-Fi intruder alerts (premium)Ransomware Shield (premium)See all anti-malware featuresAnti-malware protection for your MacYour macOS might stop some malware variants, but it can’t help you if you’re already infected. Avast’s free antiv
# ...

# %% [markdown]
# ## Reading pdf using pdfplumber

# %%
import pdfplumber

with pdfplumber.open('Page 1 Figma.pdf') as pdf:
    # iterate over each page
    for page in pdf.pages:
        # extract text
        text = page.extract_text()
    final_pdf_text = text.replace('\n',' ')

print(final_pdf_text)
# Out:
# Free aannttiivviirruuss for Mac Think differently, live safely Free download Get premium 30-day money-back guarantee Great 2022 January 2024 Approved Mac Best macOS 8,396 reviews on Security Security Hundreds of 30+ years of Award-winning Doesn’t slow your millions of users cybersecurity antivirus for Mac device worldwide expertise Your Mac is not immune to threats — but our free Mac antivirus protects you on 3 fronts Malware isn’t the only threat to your Mac. Malicious websites and vulnerable Wi-Fi networks can also jeopardize your safety and privacy. Avast Security for Mac provides more protection against all 3 threats, and our premium version also helps expose Wi-Fi intruders and helps stop ransomware. Anti-malware security Web and Email Shields Wi-Fi security scan Wi-Fi intruder alerts Ransomware Shield (premium) (premium) Anti-malware protection for your Mac Your macOS might stop some malware variants, but it can’t help you if you’re already infected. Avast’s free antivirus for 
# ...

# %% [markdown]
# ## Reading pdf using pymupdf

# %%
#pymupdf
import fitz
doc = fitz.open('Page 1 Figma.pdf')
page = doc.load_page(0)
text = page.get_text()
pdf_text = ''.join(text)
pdf_text_list = text.split('\n')
pdf_final_list = [l.replace('\n','').strip() for l in pdf_text_list if l.replace('\n','').strip()]
# Out:
# ['Award-winning ',
#  'antivirus for Mac',
#  'Doesn’t slow your ',
#  'device',
#  'Hundreds of ',
#  'millions of users ',
#  'worldwide',
#  '30+ years of ',
#  'cybersecurity ',
#  'expertise',
#  'Approved Mac ',
#  'Security',
#  '2022',
#  'Best macOS ',
#  'Security',
#  'January 2024',
#  'Great',
#  '8,396 reviews on',
#  '30-day money-back guarantee',
#  'Get premium',
#  'Free download',
#  'Think differently, live safely',
#  'Free antivirus for Mac',
#  'antivirus',
#  'Your Mac is not immune to threats — ',
#  'but our free Mac antivirus protects you on 3 fronts',
#  'Malware isn’t the only threat to your Mac. Malicious websites and vulnerable Wi-Fi networks can also jeopardize your safety and privacy. Avast ',
#  'Security for Mac provides more protection against all 3 threats, and our premium version also helps expose Wi-Fi intruders and helps stop ',
#  'ransomware.',
#  'Anti-malware security',
#  'Web and Email Shields',
#  'Wi-Fi security scan',
# ...

# %%
# pdf_text = pdf_text.replace('\n',' ')

pdf_text_final = ' '.join(pdf_final_list)
pdf_text_final
# Out:
# ['Award-winning',
#  'antivirus for Mac',
#  'Doesn’t slow your',
#  'device',
#  'Hundreds of',
#  'millions of users',
#  'worldwide',
#  '30+ years of',
#  'cybersecurity',
#  'expertise',
#  'Approved Mac',
#  'Security',
#  '2022',
#  'Best macOS',
#  'Security',
#  'January 2024',
#  'Great',
#  '8,396 reviews on',
#  '30-day money-back guarantee',
#  'Get premium',
#  'Free download',
#  'Think differently, live safely',
#  'Free antivirus for Mac',
#  'antivirus',
#  'Your Mac is not immune to threats —',
#  'but our free Mac antivirus protects you on 3 fronts',
#  'Malware isn’t the only threat to your Mac. Malicious websites and vulnerable Wi-Fi networks can also jeopardize your safety and privacy. Avast',
#  'Security for Mac provides more protection against all 3 threats, and our premium version also helps expose Wi-Fi intruders and helps stop',
#  'ransomware.',
#  'Anti-malware security',
#  'Web and Email Shields',
#  'Wi-Fi security scan',
#  'Wi-Fi intruder alerts',
# ...

# %% [markdown]
# # Reading html file

# %%
# url = "file:///C:/Users/Kunal.Keni/Desktop/assignment/assignment%205/Page%201%20HTML.html"
# html = urlopen(url).read()
# soup = BeautifulSoup(html, features="html.parser")

# words = soup.text
# words = soup.text.replace('\n\n', '\n').replace('  ','').replace('\t','').lstrip().splitlines()
# new_words = []
# for word in words:
#     if word:
#         new_words.append(word)

# %%
# sentence = new_words[4:]

# %%
# keywords = []
# for s in sentence:
#     if s not in final_pdf_text:
#         keywords.append(s)

# %%
# keywords

# %%
# !pip install -q -U google-generativeai

# %%
# def to_markdown(text):
#   text = text.replace('•', '  *')
#   return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))
# to_markdown(response.text)

# %%
# url = "file:///C:/Users/Kunal.Keni/Desktop/assignment/assignment%205/Page%201%20HTML.html"
# html = urlopen(url).read()
# soup = BeautifulSoup(html, features="html.parser")

# for script in soup(["script", "style"]):
#     script.extract()  


# text = soup.get_text()


# lines = (line.strip() for line in text.splitlines())

# chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# print(chunks)

# # text = ''.join(chunk for chunk in chunks if chunk)

# # html_text = text.split(' ')

# %%
final_pdf_text.find('guarantee Great')
# Out:
# 107

# %%
url = "file:///C:/Users/Kunal.Keni/Desktop/assignment/assignment%205/Page%201%20HTML.html"
html = urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')


text_content = soup.get_text(separator="\n")

# Split text into lines
lines = text_content.splitlines()

# Remove empty lines and strip whitespace
html_lines = [line.strip() for line in lines if line.strip()]
# print(html_lines)

html_lines
# Out:
# ['Get Free Antivirus for Mac | Avast Security',
#  'Privacy preference center',
#  'By clicking "Accept all" you allow cookies that improve your experience on our site, help us analyze site performance and usage, and enable us to show relevant marketing content. You can manage cookie settings below. By clicking “Confirm selection” you agree with the current settings. See',
#  'Cookies policy',
#  'Accept all',
#  'Manage consent settings',
#  'Necessary cookies',
#  'Always Active',
#  'Necessary cookies help make a website usable by enabling basic functions like page navigation and access to secure areas of the website. The website cannot function properly without these cookies.',
#  'Preference cookies',
#  'Preference cookies',
# ...

# %%
html_para = ' '.join(html_lines)

# %%
html_para
# Out:
# 'Get Free Antivirus for Mac | Avast Security Privacy preference center By clicking "Accept all" you allow cookies that improve your experience on our site, help us analyze site performance and usage, and enable us to show relevant marketing content. You can manage cookie settings below. By clicking “Confirm selection” you agree with the current settings. See Cookies policy Accept all Manage consent settings Necessary cookies Always Active Necessary cookies help make a website usable by enabling basic functions like page navigation and access to secure areas of the website. The website cannot function properly without these cookies. Preference cookies Preference cookies Preference cookies enable a website to remember information that changes the way the website behaves or looks, such as your preferred language or the region that you are in. De-selecting these cookies may result in improper functionality and setting of the website. Performance cookies Performance cookies Performance co
# ...

# %%
missing_in_html = []
for element_of_pdf in pdf_final_list:
    if element_of_pdf.lower() not in html_para.lower():
        missing_in_html.append(element_of_pdf)

# %%
missing_in_html
# Out:
# ['Hundreds of',
#  'millions of users',
#  'January 2024',
#  'Great',
#  '8,396 reviews on',
#  'Security for Mac provides more protection against all 3 threats, and our premium version also helps expose Wi-Fi intruders and helps stop',
#  'you’re already infected. Avast’s free antivirus for Mac not only helps',
#  'block viruses, spyware, Trojans, and other malware in real time, it also',
#  'with more protection',
#  'Even trusted websites can get hacked, and cybercriminals can easily',
#  'spoof emails from your friends or bank. Avast Security helps Mac users',
#  'to identify unsafe websites, block unsafe downloads and risky email',
#  'attachments, plus reduce web tracking via an optional extension.',
#  'Avast Security for Mac scans your network and connected devices for',
#  'Avast Premium Security helps protect your photos and files from',
#  'ransomware attacks, making it harder for cybercriminals to encrypt,',
#  'lock, or mess with your most personal memories.',
# ...

# %%
for element in missing_in_html:
    text_instances = page.search_for(element)
    for inst in text_instances:
        highlight = page.add_highlight_annot(inst)
        highlight.update()



doc.save("output.pdf", garbage=4, deflate=True, clean=True)

# %%
# !pip install --upgrade pymupdf
# Out:
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.2 MB 660.6 kB/s eta 0:00:05
#    -- ------------------------------------- 0.2/3.2 MB 2.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.4/3.2 MB 3.1 MB/s eta 0:00:01
#    ------ --------------------------------- 0.5/3.2 MB 3.4 MB/s eta 0:00:01
#    ------- -------------------------------- 0.6/3.2 MB 3.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.9/3.2 MB 3.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.0/3.2 MB 3.6 MB/s eta 0:00:01
#    -------------- ------------------------- 1.2/3.2 MB 3.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.3/3.2 MB 3.7 MB/s eta 0:00:01
#    --------------------- ------------------ 1.7/3.2 MB 4.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.9/3.2 MB 4.2 MB/s eta 0:00:01
# ...
